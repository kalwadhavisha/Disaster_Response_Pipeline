# %% [markdown]
# # ML Pipeline Preparation

# %% [markdown]
# ### Importing libraries and loading data from database.¶
# 1. Importing Python libraries
# 2. Loading dataset from database with read_sql_table
# 3. Defining feature and target variables X and Y

# %%
# import libraries
import pandas as pd
import numpy as np
import os
import pickle
from sqlalchemy import create_engine
import re
import nltk
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,AdaBoostClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score, f1_score, fbeta_score, classification_report
from scipy.stats import hmean
from scipy.stats.mstats import gmean

nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/havishamadhu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/havishamadhu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/havishamadhu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# load data from database
cwd = os.getcwd()
dbwd = cwd.replace('/models','/data/').replace('\\models','\\data\\')
engine = create_engine('sqlite:///'+dbwd+'DisasterResponse.db')
df = pd.read_sql_table('df',engine)
X = df['message']
Y = df.iloc[:,4:]

# %% [markdown]
# ### Tokenized function to process the text data

# %%
def tokenize(text):
    url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")

    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### Building a Machine Learning Pipeline

# %%
class StartingVerbExtractor(BaseEstimator, TransformerMixin):

    def starting_verb(self, text):
        sentence_list = nltk.sent_tokenize(text)
        for sentence in sentence_list:
            pos_tags = nltk.pos_tag(tokenize(sentence))
            first_word, first_tag = pos_tags[0]
            if first_tag in ['VB', 'VBP'] or first_word == 'RT':
                return True
        return False

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_tagged = pd.Series(X).apply(self.starting_verb)
        return pd.DataFrame(X_tagged)

# %%
# This machine pipeline should take in the message column as input and output 
# classification results on the other 36 categories in the dataset. 

def model_pipeline():
    pipeline = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('vect', CountVectorizer(tokenizer=tokenize)),
                ('tfidf', TfidfTransformer())
            ])),

            ('starting_verb', StartingVerbExtractor())
        ])),

        ('clf', MultiOutputClassifier(AdaBoostClassifier()))
    ])

    return pipeline

# %% [markdown]
# ### Splitting data into training and test sets and training the pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)

model = []
model = model_pipeline()
model.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('features',
#                  FeatureUnion(n_jobs=None,
#                               transformer_list=[('text_pipeline',
#                                                  Pipeline(memory=None,
#                                                           steps=[('vect',
#                                                                   CountVectorizer(analyzer='word',
#                                                                                   binary=False,
#                                                                                   decode_error='strict',
#                                                                                   dtype=<class 'numpy.int64'>,
#                                                                                   encoding='utf-8',
#                                                                                   input='content',
#                                                                                   lowercase=True,
#                                                                                   max_df=1.0,
#                                                                                   max_features=None,
#                                                                                   min_df=1,
#                                                                                   ngram_range=(1,
#                                                                                                1),
#                                                                                   preprocessor=Non...
#                                                                   TfidfTransformer(norm='l2',
#                                                                                    smooth_idf=True,
#                                                                                    sublinear_tf=False,
#                                                                                    use_idf=True))],
#                                                           verbose=False)),
#                                                 ('starting_verb',
#                                                  StartingVerbExtractor())],
#                               transformer_weights=None, verbose=False)),
#                 ('clf',
#                  MultiOutputClassifier(estimator=AdaBoostClassifier(algorithm='SAMME.R',
#                                                                     base_estimator=None,
#                                                                     learning_rate=1.0,
#                                                                     n_estimators=50,
#                                                                     random_state=None),
#                                        n_jobs=None))],
#          verbose=False)

# %% [markdown]
# ### Testing the Model

# %%
y_pred = model.predict(X_test)

# %%
overall_accuracy = (y_pred == y_test).mean().mean()

print('Average overall accuracy {0:.2f}% \n'.format(overall_accuracy*100))
# Out:
# Average overall accuracy 95.25%

# %%
y_pred_pd = pd.DataFrame(y_pred, columns = y_test.columns)
for column in y_test.columns:
    print('***********************************************************\n')
    print('Column Name: {}\n'.format(column))
    print(classification_report(y_test[column],y_pred_pd[column]))
# Out:
# ***********************************************************
#
# Column Name: request
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      5454
#            1       0.77      0.54      0.64      1100
#
#     accuracy                           0.90      6554
#    macro avg       0.84      0.76      0.79      6554
# weighted avg       0.89      0.90      0.89      6554
#
# ***********************************************************
#
# Column Name: offer
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6529
#            1       0.00      0.00      0.00        25
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# ***********************************************************
#
# Column Name: aid_related
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80      3810
#            1       0.77      0.58      0.66      2744
#
#     accuracy                           0.75      6554
#    macro avg       0.76      0.73      0.73      6554
# weighted avg       0.76      0.75      0.75      6554
#
# ***********************************************************
#
# Column Name: medical_help
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      6020
#            1       0.62      0.28      0.38       534
#
#     accuracy                           0.93      6554
#    macro avg       0.78      0.63      0.67      6554
# weighted avg       0.91      0.93      0.91      6554
#
# ***********************************************************
#
# Column Name: medical_products
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6230
#            1       0.62      0.29      0.39       324
#
#     accuracy                           0.96      6554
#    macro avg       0.79      0.64      0.69      6554
# weighted avg       0.95      0.96      0.95      6554
#
# ***********************************************************
#
# Column Name: search_and_rescue
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6372
#            1       0.69      0.23      0.34       182
#
#     accuracy                           0.98      6554
#    macro avg       0.84      0.61      0.66      6554
# weighted avg       0.97      0.98      0.97      6554
#
# ***********************************************************
#
# Column Name: security
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6432
#            1       0.19      0.03      0.06       122
#
#     accuracy                           0.98      6554
#    macro avg       0.59      0.52      0.52      6554
# weighted avg       0.97      0.98      0.97      6554
#
# ***********************************************************
#
# Column Name: military
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6341
#            1       0.62      0.31      0.41       213
#
#     accuracy                           0.97      6554
#    macro avg       0.80      0.65      0.70      6554
# weighted avg       0.97      0.97      0.97      6554
#
# ***********************************************************
#
# Column Name: child_alone
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6554
#
#     accuracy                           1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# ***********************************************************
#
# Column Name: water
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6103
#            1       0.77      0.60      0.67       451
#
#     accuracy                           0.96      6554
#    macro avg       0.87      0.79      0.83      6554
# weighted avg       0.96      0.96      0.96      6554
#
# ***********************************************************
#
# Column Name: food
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      5851
#            1       0.80      0.70      0.75       703
#
#     accuracy                           0.95      6554
#    macro avg       0.88      0.84      0.86      6554
# weighted avg       0.95      0.95      0.95      6554
#
# ***********************************************************
#
# Column Name: shelter
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      5999
#            1       0.76      0.50      0.61       555
#
#     accuracy                           0.94      6554
#    macro avg       0.86      0.74      0.79      6554
# weighted avg       0.94      0.94      0.94      6554
#
# ***********************************************************
#
# Column Name: clothing
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6446
#            1       0.76      0.41      0.53       108
#
#     accuracy                           0.99      6554
#    macro avg       0.87      0.70      0.76      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ***********************************************************
#
# Column Name: money
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      6393
#            1       0.54      0.35      0.43       161
#
#     accuracy                           0.98      6554
#    macro avg       0.76      0.67      0.71      6554
# weighted avg       0.97      0.98      0.97      6554
#
# ***********************************************************
#
# Column Name: missing_people
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6481
#            1       0.50      0.21      0.29        73
#
#     accuracy                           0.99      6554
#    macro avg       0.75      0.60      0.64      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ***********************************************************
#
# Column Name: refugees
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      6342
#            1       0.58      0.26      0.36       212
#
#     accuracy                           0.97      6554
#    macro avg       0.78      0.63      0.67      6554
# weighted avg       0.96      0.97      0.96      6554
#
# ***********************************************************
#
# Column Name: death
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6233
#            1       0.82      0.45      0.59       321
#
#     accuracy                           0.97      6554
#    macro avg       0.90      0.72      0.79      6554
# weighted avg       0.97      0.97      0.96      6554
#
# ***********************************************************
#
# Column Name: other_aid
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      5673
#            1       0.47      0.12      0.19       881
#
#     accuracy                           0.86      6554
#    macro avg       0.67      0.55      0.56      6554
# weighted avg       0.82      0.86      0.83      6554
#
# ***********************************************************
#
# Column Name: infrastructure_related
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      6152
#            1       0.41      0.10      0.16       402
#
#     accuracy                           0.94      6554
#    macro avg       0.67      0.55      0.56      6554
# weighted avg       0.91      0.94      0.92      6554
#
# ***********************************************************
#
# Column Name: transport
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6255
#            1       0.64      0.18      0.28       299
#
#     accuracy                           0.96      6554
#    macro avg       0.80      0.59      0.63      6554
# weighted avg       0.95      0.96      0.95      6554
#
# ***********************************************************
#
# Column Name: buildings
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      6247
#            1       0.57      0.36      0.44       307
#
#     accuracy                           0.96      6554
#    macro avg       0.77      0.67      0.71      6554
# weighted avg       0.95      0.96      0.95      6554
#
# ***********************************************************
#
# Column Name: electricity
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6413
#            1       0.54      0.23      0.32       141
#
#     accuracy                           0.98      6554
#    macro avg       0.76      0.61      0.65      6554
# weighted avg       0.97      0.98      0.98      6554
#
# ***********************************************************
#
# Column Name: tools
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6508
#            1       0.30      0.07      0.11        46
#
#     accuracy                           0.99      6554
#    macro avg       0.65      0.53      0.55      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ***********************************************************
#
# Column Name: hospitals
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6487
#            1       0.29      0.09      0.14        67
#
#     accuracy                           0.99      6554
#    macro avg       0.64      0.54      0.57      6554
# weighted avg       0.98      0.99      0.99      6554
#
# ***********************************************************
#
# Column Name: shops
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6527
#            1       0.00      0.00      0.00        27
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# ***********************************************************
#
# Column Name: aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6495
#            1       0.09      0.03      0.05        59
#
#     accuracy                           0.99      6554
#    macro avg       0.54      0.52      0.52      6554
# weighted avg       0.98      0.99      0.99      6554
#
# ***********************************************************
#
# Column Name: other_infrastructure
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6272
#            1       0.40      0.09      0.14       282
#
#     accuracy                           0.95      6554
#    macro avg       0.68      0.54      0.56      6554
# weighted avg       0.94      0.95      0.94      6554
#
# ***********************************************************
#
# Column Name: weather_related
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      4767
#            1       0.85      0.66      0.74      1787
#
#     accuracy                           0.88      6554
#    macro avg       0.87      0.81      0.83      6554
# weighted avg       0.87      0.88      0.87      6554
#
# ***********************************************************
#
# Column Name: floods
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      6028
#            1       0.85      0.53      0.65       526
#
#     accuracy                           0.95      6554
#    macro avg       0.90      0.76      0.81      6554
# weighted avg       0.95      0.95      0.95      6554
#
# ***********************************************************
#
# Column Name: storm
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      5961
#            1       0.78      0.51      0.61       593
#
#     accuracy                           0.94      6554
#    macro avg       0.86      0.75      0.79      6554
# weighted avg       0.94      0.94      0.94      6554
#
# ***********************************************************
#
# Column Name: fire
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6492
#            1       0.46      0.18      0.26        62
#
#     accuracy                           0.99      6554
#    macro avg       0.73      0.59      0.63      6554
# weighted avg       0.99      0.99      0.99      6554
#
# ***********************************************************
#
# Column Name: earthquake
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5932
#            1       0.88      0.78      0.82       622
#
#     accuracy                           0.97      6554
#    macro avg       0.93      0.88      0.90      6554
# weighted avg       0.97      0.97      0.97      6554
#
# ***********************************************************
#
# Column Name: cold
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6430
#            1       0.79      0.33      0.47       124
#
#     accuracy                           0.99      6554
#    macro avg       0.89      0.66      0.73      6554
# weighted avg       0.98      0.99      0.98      6554
#
# ***********************************************************
#
# Column Name: other_weather
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      6236
#            1       0.46      0.15      0.23       318
#
#     accuracy                           0.95      6554
#    macro avg       0.71      0.57      0.60      6554
# weighted avg       0.93      0.95      0.94      6554
#
# ***********************************************************
#
# Column Name: direct_report
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      5287
#            1       0.74      0.49      0.59      1267
#
#     accuracy                           0.87      6554
#    macro avg       0.81      0.72      0.76      6554
# weighted avg       0.86      0.87      0.86      6554
#
# ***********************************************************
#
# Column Name: direct
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      3917
#            1       0.92      0.93      0.92      2637
#
#     accuracy                           0.94      6554
#    macro avg       0.93      0.94      0.93      6554
# weighted avg       0.94      0.94      0.94      6554
#
# ***********************************************************
#
# Column Name: news
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96      3223
#            1       0.96      0.95      0.96      3331
#
#     accuracy                           0.96      6554
#    macro avg       0.96      0.96      0.96      6554
# weighted avg       0.96      0.96      0.96      6554

# %% [markdown]
# ### Exporting the model as a pickle file

# %%
# save the model to disk
filename = 'classifier.pickle'
pickle.dump(model, open(filename, 'wb'))
